# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import zipfile
path_to_zip_file = "/content/gdrive/MyDrive/dataset3.zip"
directory_to_extract_to = "/content/dataset3"
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
# !pip install torchsummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.9/dist-packages (1.5.1)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader,random_split
from torchvision import datasets, transforms, models 
from torchvision.utils import make_grid
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc
import torch.optim as optim
from tqdm import tqdm
from torchsummary import summary


import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

from sklearn.metrics import confusion_matrix
import seaborn as sns

import shutil

import warnings
warnings.filterwarnings("ignore")

# %%
BATCH_SIZE = 128
LR = 0.00005

# %%
train_transform=transforms.Compose([
        transforms.RandomRotation(10),      # rotate +/- 10 degrees
        transforms.RandomHorizontalFlip(),  # reverse 50% of images
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
])

# %% [markdown]
# # Set Train and Test

# %%
output_dir = "/content/dataset3/flowers"

# %%
dataset=datasets.ImageFolder(root=(output_dir),transform=train_transform)
dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 15740
#     Root location: /content/dataset3/flowers
#     StandardTransform
# Transform: Compose(
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                RandomHorizontalFlip(p=0.5)
#                Resize(size=224, interpolation=bilinear, max_size=None, antialias=warn)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
class_names=dataset.classes
print(class_names)
print(len(class_names))
# Out:
# ['astilbe', 'bellflower', 'black_eyed_susan', 'calendula', 'california_poppy', 'carnation', 'common_daisy', 'coreopsis', 'daffodil', 'dandelion', 'iris', 'magnolia', 'rose', 'sunflower', 'tulip', 'water_lily']
# 16

# %%
train_size = int(0.7 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])

# %%
# Define the dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# Get the class-to-index dictionary from the original dataset
class_to_idx = train_dataset.dataset.class_to_idx

# Loop over the train dataloader and print two images for each class
for i, cls in enumerate(class_names):
    cls_idx = class_to_idx[cls]
    cls_samples = []
    for j, sample in enumerate(train_dataset):
        if sample[1] == cls_idx:
            cls_samples.append(sample[0])
        if len(cls_samples) == 2:
            break
    plt.figure(figsize=(8, 4))
    plt.suptitle(cls)
    for k, image in enumerate(cls_samples):
        plt.subplot(1, 2, k+1)
        plt.imshow(image.permute(1, 2, 0))
        plt.axis('off')
    plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class MobileNetV2(nn.Module):
    def __init__(self, num_classes=5):
        super(MobileNetV2, self).__init__()
        self.features = models.mobilenet_v2(pretrained=False).features
        self.classifier = nn.Linear(1280, num_classes)

    def forward(self, x):
        x = self.features(x)
        x = nn.functional.adaptive_avg_pool2d(x, 1).reshape(x.shape[0], -1)
        x = self.classifier(x)
        return x

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# Initialize the model and move it to the device
model = MobileNetV2(num_classes = len(class_names)).to(device)

# %%
# Display the model summary
summary(model, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 112, 112]             864
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#              ReLU6-3         [-1, 32, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112]             288
#        BatchNorm2d-5         [-1, 32, 112, 112]              64
#              ReLU6-6         [-1, 32, 112, 112]               0
#             Conv2d-7         [-1, 16, 112, 112]             512
#        BatchNorm2d-8         [-1, 16, 112, 112]              32
#   InvertedResidual-9         [-1, 16, 112, 112]               0
#            Conv2d-10         [-1, 96, 112, 112]           1,536
#       BatchNorm2d-11         [-1, 96, 112, 112]             192
#             ReLU6-12         [-1, 96, 112, 112]               0
#            Conv2d-13           [-1, 96, 56, 56]             864
#       BatchNorm2d-14           [-1, 96, 56, 56]             192
#             ReLU6-15           [-1, 96, 56, 56]               0
#            Conv2d-16           [-1, 24, 56, 56]           2,304
#       BatchNorm2d-17           [-1, 24, 56, 56]              48
#  InvertedResidual-18           [-1, 24, 56, 56]               0
#            Conv2d-19          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-20          [-1, 144, 56, 56]             288
#             ReLU6-21          [-1, 144, 56, 56]               0
#            Conv2d-22          [-1, 144, 56, 56]           1,296
#       BatchNorm2d-23          [-1, 144, 56, 56]             288
#             ReLU6-24          [-1, 144, 56, 56]               0
#            Conv2d-25           [-1, 24, 56, 56]           3,456
#       BatchNorm2d-26           [-1, 24, 56, 56]              48
#  InvertedResidual-27           [-1, 24, 56, 56]               0
#            Conv2d-28          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-29          [-1, 144, 56, 56]             288
#             ReLU6-30          [-1, 144, 56, 56]               0
#            Conv2d-31          [-1, 144, 28, 28]           1,296
#       BatchNorm2d-32          [-1, 144, 28, 28]             288
#             ReLU6-33          [-1, 144, 28, 28]               0
#            Conv2d-34           [-1, 32, 28, 28]           4,608
#       BatchNorm2d-35           [-1, 32, 28, 28]              64
#  InvertedResidual-36           [-1, 32, 28, 28]               0
#            Conv2d-37          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-38          [-1, 192, 28, 28]             384
#             ReLU6-39          [-1, 192, 28, 28]               0
#            Conv2d-40          [-1, 192, 28, 28]           1,728
#       BatchNorm2d-41          [-1, 192, 28, 28]             384
#             ReLU6-42          [-1, 192, 28, 28]               0
#            Conv2d-43           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-44           [-1, 32, 28, 28]              64
#  InvertedResidual-45           [-1, 32, 28, 28]               0
#            Conv2d-46          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-47          [-1, 192, 28, 28]             384
#             ReLU6-48          [-1, 192, 28, 28]               0
#            Conv2d-49          [-1, 192, 28, 28]           1,728
#       BatchNorm2d-50          [-1, 192, 28, 28]             384
#             ReLU6-51          [-1, 192, 28, 28]               0
#            Conv2d-52           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-53           [-1, 32, 28, 28]              64
#  InvertedResidual-54           [-1, 32, 28, 28]               0
#            Conv2d-55          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-56          [-1, 192, 28, 28]             384
#             ReLU6-57          [-1, 192, 28, 28]               0
#            Conv2d-58          [-1, 192, 14, 14]           1,728
#       BatchNorm2d-59          [-1, 192, 14, 14]             384
#             ReLU6-60          [-1, 192, 14, 14]               0
#            Conv2d-61           [-1, 64, 14, 14]          12,288
#       BatchNorm2d-62           [-1, 64, 14, 14]             128
#  InvertedResidual-63           [-1, 64, 14, 14]               0
#            Conv2d-64          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-65          [-1, 384, 14, 14]             768
#             ReLU6-66          [-1, 384, 14, 14]               0
#            Conv2d-67          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-68          [-1, 384, 14, 14]             768
#             ReLU6-69          [-1, 384, 14, 14]               0
#            Conv2d-70           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-71           [-1, 64, 14, 14]             128
#  InvertedResidual-72           [-1, 64, 14, 14]               0
#            Conv2d-73          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-74          [-1, 384, 14, 14]             768
#             ReLU6-75          [-1, 384, 14, 14]               0
#            Conv2d-76          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-77          [-1, 384, 14, 14]             768
#             ReLU6-78          [-1, 384, 14, 14]               0
#            Conv2d-79           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-80           [-1, 64, 14, 14]             128
#  InvertedResidual-81           [-1, 64, 14, 14]               0
#            Conv2d-82          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-83          [-1, 384, 14, 14]             768
#             ReLU6-84          [-1, 384, 14, 14]               0
#            Conv2d-85          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-86          [-1, 384, 14, 14]             768
#             ReLU6-87          [-1, 384, 14, 14]               0
#            Conv2d-88           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-89           [-1, 64, 14, 14]             128
#  InvertedResidual-90           [-1, 64, 14, 14]               0
#            Conv2d-91          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-92          [-1, 384, 14, 14]             768
#             ReLU6-93          [-1, 384, 14, 14]               0
#            Conv2d-94          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-95          [-1, 384, 14, 14]             768
#             ReLU6-96          [-1, 384, 14, 14]               0
#            Conv2d-97           [-1, 96, 14, 14]          36,864
#       BatchNorm2d-98           [-1, 96, 14, 14]             192
#  InvertedResidual-99           [-1, 96, 14, 14]               0
#           Conv2d-100          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-101          [-1, 576, 14, 14]           1,152
#            ReLU6-102          [-1, 576, 14, 14]               0
#           Conv2d-103          [-1, 576, 14, 14]           5,184
#      BatchNorm2d-104          [-1, 576, 14, 14]           1,152
#            ReLU6-105          [-1, 576, 14, 14]               0
#           Conv2d-106           [-1, 96, 14, 14]          55,296
#      BatchNorm2d-107           [-1, 96, 14, 14]             192
# InvertedResidual-108           [-1, 96, 14, 14]               0
#           Conv2d-109          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-110          [-1, 576, 14, 14]           1,152
#            ReLU6-111          [-1, 576, 14, 14]               0
#           Conv2d-112          [-1, 576, 14, 14]           5,184
#      BatchNorm2d-113          [-1, 576, 14, 14]           1,152
#            ReLU6-114          [-1, 576, 14, 14]               0
#           Conv2d-115           [-1, 96, 14, 14]          55,296
#      BatchNorm2d-116           [-1, 96, 14, 14]             192
# InvertedResidual-117           [-1, 96, 14, 14]               0
#           Conv2d-118          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-119          [-1, 576, 14, 14]           1,152
#            ReLU6-120          [-1, 576, 14, 14]               0
#           Conv2d-121            [-1, 576, 7, 7]           5,184
#      BatchNorm2d-122            [-1, 576, 7, 7]           1,152
#            ReLU6-123            [-1, 576, 7, 7]               0
#           Conv2d-124            [-1, 160, 7, 7]          92,160
#      BatchNorm2d-125            [-1, 160, 7, 7]             320
# InvertedResidual-126            [-1, 160, 7, 7]               0
#           Conv2d-127            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-128            [-1, 960, 7, 7]           1,920
#            ReLU6-129            [-1, 960, 7, 7]               0
#           Conv2d-130            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-131            [-1, 960, 7, 7]           1,920
#            ReLU6-132            [-1, 960, 7, 7]               0
#           Conv2d-133            [-1, 160, 7, 7]         153,600
#      BatchNorm2d-134            [-1, 160, 7, 7]             320
# InvertedResidual-135            [-1, 160, 7, 7]               0
#           Conv2d-136            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-137            [-1, 960, 7, 7]           1,920
#            ReLU6-138            [-1, 960, 7, 7]               0
#           Conv2d-139            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-140            [-1, 960, 7, 7]           1,920
#            ReLU6-141            [-1, 960, 7, 7]               0
#           Conv2d-142            [-1, 160, 7, 7]         153,600
#      BatchNorm2d-143            [-1, 160, 7, 7]             320
# InvertedResidual-144            [-1, 160, 7, 7]               0
#           Conv2d-145            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-146            [-1, 960, 7, 7]           1,920
#            ReLU6-147            [-1, 960, 7, 7]               0
#           Conv2d-148            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-149            [-1, 960, 7, 7]           1,920
#            ReLU6-150            [-1, 960, 7, 7]               0
#           Conv2d-151            [-1, 320, 7, 7]         307,200
#      BatchNorm2d-152            [-1, 320, 7, 7]             640
# InvertedResidual-153            [-1, 320, 7, 7]               0
#           Conv2d-154           [-1, 1280, 7, 7]         409,600
#      BatchNorm2d-155           [-1, 1280, 7, 7]           2,560
#            ReLU6-156           [-1, 1280, 7, 7]               0
#           Linear-157                   [-1, 16]          20,496
# ================================================================
# Total params: 2,244,368
# Trainable params: 2,244,368
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 152.85
# Params size (MB): 8.56
# Estimated Total Size (MB): 161.99
# ----------------------------------------------------------------

# %%
# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR)

# %%
# Train the model
num_epochs = 100
train_losses = []
val_losses = []
best_val_loss = float('inf')
patience = 15  # number of epochs to wait for improvement
metrics = []
import time

start_time = time.monotonic()


for epoch in range(num_epochs):
    print(f"Now starting epoch: {epoch+1}")
    # Train the model on the training set

    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(train_dataloader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Calculate the training loss
    train_loss = running_loss / len(train_dataloader)
    train_losses.append(train_loss)
    train_accuracy = 100 * correct / total
    #print('Epoch [%d/%d], Train Loss: %.4f' % (epoch+1, num_epochs, train_loss))
    print('Epoch [%d/%d], Train Loss: %.4f, Train Accuracy: %.2f %%' % (epoch+1, num_epochs, train_loss, train_accuracy))

    """model.train()
    with torch.no_grad():
        running_loss = 0.0
        correct = 0
        total = 0
        for i, data in enumerate(train_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # Calculate the training loss and accuracy
        train_loss = running_loss / len(train_dataloader)
        train_losses.append(train_loss)
        train_accuracy = 100 * correct / total
        print('Epoch [%d/%d], Train Loss: %.4f, Train Accuracy: %.2f %%' % (epoch+1, num_epochs, train_loss, train_accuracy))"""

    # Evaluate the model on the validation set
    model.eval()
    with torch.no_grad():
        running_loss = 0.0
        correct = 0
        total = 0
        for i, data in enumerate(val_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # Calculate the validation loss and accuracy
        val_loss = running_loss / len(val_dataloader)
        val_losses.append(val_loss)
        val_accuracy = 100 * correct / total
        print('Epoch [%d/%d], Validation Loss: %.4f, Validation Accuracy: %.2f %%' % (epoch+1, num_epochs, val_loss, val_accuracy))
        metrics.append([epoch+1,train_loss,val_loss,train_accuracy,val_accuracy])

        
        # Checkpoint the model if the validation loss has improved (Early stopping)
        if val_loss < best_val_loss:
            print("Saving model checkpoint...")
            best_val_loss = val_loss
            checkpoint = {'epoch': epoch+1,
                          'state_dict': model.state_dict(),
                          'optimizer': optimizer.state_dict(),
                          'train_loss': train_loss,
                          'val_loss': val_loss}
            torch.save(checkpoint, 'd1_mnv2_model_checkpoint.pth')
            patience_counter = 0
        else:
            patience_counter += 1
            print(f"Validation loss did not improve. Patience left: {patience - patience_counter}")
            if patience_counter >= patience:
                print("Stopping training due to early stopping...")
                break
        
    # Switch the model back to training mode
    model.train()

print('Finished Training')

# Your code goes here

end_time = time.monotonic()
elapsed_time = end_time - start_time

print(f"Time elapsed: {elapsed_time:.2f} seconds")

# Plot the training and validation loss
plt.plot(train_losses, label='Training loss')
plt.plot(val_losses, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Now starting epoch: 1
# Epoch [1/100], Train Loss: 2.6857, Train Accuracy: 12.29 %
# Epoch [1/100], Validation Loss: 2.6381, Validation Accuracy: 11.94 %
# Saving model checkpoint...
# Now starting epoch: 2
# Epoch [2/100], Train Loss: 2.3682, Train Accuracy: 21.08 %
# Epoch [2/100], Validation Loss: 2.1678, Validation Accuracy: 24.71 %
# Saving model checkpoint...
# Now starting epoch: 3
# Epoch [3/100], Train Loss: 2.0846, Train Accuracy: 27.71 %
# Epoch [3/100], Validation Loss: 2.0002, Validation Accuracy: 31.39 %
# Saving model checkpoint...
# Now starting epoch: 4
# Epoch [4/100], Train Loss: 1.9258, Train Accuracy: 33.60 %
# Epoch [4/100], Validation Loss: 1.8627, Validation Accuracy: 34.88 %
# Saving model checkpoint...
# Now starting epoch: 5
# Epoch [5/100], Train Loss: 1.8067, Train Accuracy: 37.06 %
# Epoch [5/100], Validation Loss: 1.7537, Validation Accuracy: 40.28 %
# Saving model checkpoint...
# Now starting epoch: 6
# Epoch [6/100], Train Loss: 1.7043, Train Accuracy: 41.46 %
# Epoch [6/100], Validation Loss: 1.6805, Validation Accuracy: 43.27 %
# Saving model checkpoint...
# Now starting epoch: 7
# Epoch [7/100], Train Loss: 1.6285, Train Accuracy: 44.50 %
# Epoch [7/100], Validation Loss: 1.6068, Validation Accuracy: 44.60 %
# Saving model checkpoint...
# Now starting epoch: 8
# Epoch [8/100], Train Loss: 1.5508, Train Accuracy: 46.71 %
# Epoch [8/100], Validation Loss: 1.5343, Validation Accuracy: 47.97 %
# Saving model checkpoint...
# Now starting epoch: 9
# Epoch [9/100], Train Loss: 1.4878, Train Accuracy: 49.45 %
# Epoch [9/100], Validation Loss: 1.4584, Validation Accuracy: 49.62 %
# Saving model checkpoint...
# Now starting epoch: 10
# Epoch [10/100], Train Loss: 1.4326, Train Accuracy: 50.37 %
# Epoch [10/100], Validation Loss: 1.4654, Validation Accuracy: 51.65 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 11
# Epoch [11/100], Train Loss: 1.3652, Train Accuracy: 53.35 %
# Epoch [11/100], Validation Loss: 1.3812, Validation Accuracy: 53.37 %
# Saving model checkpoint...
# Now starting epoch: 12
# Epoch [12/100], Train Loss: 1.3392, Train Accuracy: 54.36 %
# Epoch [12/100], Validation Loss: 1.3138, Validation Accuracy: 56.16 %
# Saving model checkpoint...
# Now starting epoch: 13
# Epoch [13/100], Train Loss: 1.2982, Train Accuracy: 55.88 %
# Epoch [13/100], Validation Loss: 1.3184, Validation Accuracy: 55.91 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 14
# Epoch [14/100], Train Loss: 1.2632, Train Accuracy: 56.77 %
# Epoch [14/100], Validation Loss: 1.2724, Validation Accuracy: 57.31 %
# Saving model checkpoint...
# Now starting epoch: 15
# Epoch [15/100], Train Loss: 1.2138, Train Accuracy: 58.37 %
# Epoch [15/100], Validation Loss: 1.2225, Validation Accuracy: 60.67 %
# Saving model checkpoint...
# Now starting epoch: 16
# Epoch [16/100], Train Loss: 1.1831, Train Accuracy: 60.21 %
# Epoch [16/100], Validation Loss: 1.2322, Validation Accuracy: 59.91 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 17
# Epoch [17/100], Train Loss: 1.1490, Train Accuracy: 61.15 %
# Epoch [17/100], Validation Loss: 1.1596, Validation Accuracy: 62.07 %
# Saving model checkpoint...
# Now starting epoch: 18
# Epoch [18/100], Train Loss: 1.1245, Train Accuracy: 62.39 %
# Epoch [18/100], Validation Loss: 1.1407, Validation Accuracy: 61.63 %
# Saving model checkpoint...
# Now starting epoch: 19
# Epoch [19/100], Train Loss: 1.0826, Train Accuracy: 63.32 %
# Epoch [19/100], Validation Loss: 1.1074, Validation Accuracy: 63.72 %
# Saving model checkpoint...
# Now starting epoch: 20
# Epoch [20/100], Train Loss: 1.0661, Train Accuracy: 63.96 %
# Epoch [20/100], Validation Loss: 1.1271, Validation Accuracy: 61.75 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 21
# Epoch [21/100], Train Loss: 1.0249, Train Accuracy: 65.19 %
# Epoch [21/100], Validation Loss: 1.0898, Validation Accuracy: 63.98 %
# Saving model checkpoint...
# Now starting epoch: 22
# Epoch [22/100], Train Loss: 1.0006, Train Accuracy: 66.55 %
# Epoch [22/100], Validation Loss: 1.0893, Validation Accuracy: 65.18 %
# Saving model checkpoint...
# Now starting epoch: 23
# Epoch [23/100], Train Loss: 0.9728, Train Accuracy: 67.56 %
# Epoch [23/100], Validation Loss: 1.0397, Validation Accuracy: 65.44 %
# Saving model checkpoint...
# Now starting epoch: 24
# Epoch [24/100], Train Loss: 0.9465, Train Accuracy: 68.06 %
# Epoch [24/100], Validation Loss: 1.0157, Validation Accuracy: 66.14 %
# Saving model checkpoint...
# Now starting epoch: 25
# Epoch [25/100], Train Loss: 0.9295, Train Accuracy: 68.91 %
# Epoch [25/100], Validation Loss: 0.9972, Validation Accuracy: 66.77 %
# Saving model checkpoint...
# Now starting epoch: 26
# Epoch [26/100], Train Loss: 0.9053, Train Accuracy: 69.65 %
# Epoch [26/100], Validation Loss: 0.9733, Validation Accuracy: 67.22 %
# Saving model checkpoint...
# Now starting epoch: 27
# Epoch [27/100], Train Loss: 0.8789, Train Accuracy: 70.09 %
# Epoch [27/100], Validation Loss: 0.9720, Validation Accuracy: 66.84 %
# Saving model checkpoint...
# Now starting epoch: 28
# Epoch [28/100], Train Loss: 0.8557, Train Accuracy: 71.18 %
# Epoch [28/100], Validation Loss: 0.9320, Validation Accuracy: 69.63 %
# Saving model checkpoint...
# Now starting epoch: 29
# Epoch [29/100], Train Loss: 0.8320, Train Accuracy: 71.92 %
# Epoch [29/100], Validation Loss: 0.9230, Validation Accuracy: 69.50 %
# Saving model checkpoint...
# Now starting epoch: 30
# Epoch [30/100], Train Loss: 0.8122, Train Accuracy: 72.61 %
# Epoch [30/100], Validation Loss: 0.9632, Validation Accuracy: 67.41 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 31
# Epoch [31/100], Train Loss: 0.8092, Train Accuracy: 72.70 %
# Epoch [31/100], Validation Loss: 0.9287, Validation Accuracy: 69.63 %
# Validation loss did not improve. Patience left: 13
# Now starting epoch: 32
# Epoch [32/100], Train Loss: 0.7886, Train Accuracy: 73.12 %
# Epoch [32/100], Validation Loss: 0.9129, Validation Accuracy: 69.31 %
# Saving model checkpoint...
# Now starting epoch: 33
# Epoch [33/100], Train Loss: 0.7777, Train Accuracy: 73.82 %
# Epoch [33/100], Validation Loss: 0.9076, Validation Accuracy: 70.27 %
# Saving model checkpoint...
# Now starting epoch: 34
# Epoch [34/100], Train Loss: 0.7612, Train Accuracy: 74.43 %
# Epoch [34/100], Validation Loss: 0.9157, Validation Accuracy: 69.25 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 35
# Epoch [35/100], Train Loss: 0.7416, Train Accuracy: 75.22 %
# Epoch [35/100], Validation Loss: 0.9172, Validation Accuracy: 69.25 %
# Validation loss did not improve. Patience left: 13
# Now starting epoch: 36
# Epoch [36/100], Train Loss: 0.7169, Train Accuracy: 75.52 %
# Epoch [36/100], Validation Loss: 0.8531, Validation Accuracy: 71.16 %
# Saving model checkpoint...
# Now starting epoch: 37
# Epoch [37/100], Train Loss: 0.7078, Train Accuracy: 75.60 %
# Epoch [37/100], Validation Loss: 0.8564, Validation Accuracy: 72.62 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 38
# Epoch [38/100], Train Loss: 0.7004, Train Accuracy: 76.53 %
# Epoch [38/100], Validation Loss: 0.8628, Validation Accuracy: 70.97 %
# Validation loss did not improve. Patience left: 13
# Now starting epoch: 39
# Epoch [39/100], Train Loss: 0.6772, Train Accuracy: 77.60 %
# Epoch [39/100], Validation Loss: 0.8542, Validation Accuracy: 71.73 %
# Validation loss did not improve. Patience left: 12
# Now starting epoch: 40
# Epoch [40/100], Train Loss: 0.6704, Train Accuracy: 77.88 %
# Epoch [40/100], Validation Loss: 0.8850, Validation Accuracy: 70.97 %
# Validation loss did not improve. Patience left: 11
# Now starting epoch: 41
# Epoch [41/100], Train Loss: 0.6642, Train Accuracy: 77.47 %
# Epoch [41/100], Validation Loss: 0.8271, Validation Accuracy: 72.43 %
# Saving model checkpoint...
# Now starting epoch: 42
# Epoch [42/100], Train Loss: 0.6333, Train Accuracy: 78.63 %
# Epoch [42/100], Validation Loss: 0.8626, Validation Accuracy: 72.30 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 43
# Epoch [43/100], Train Loss: 0.6282, Train Accuracy: 78.88 %
# Epoch [43/100], Validation Loss: 0.8721, Validation Accuracy: 71.47 %
# Validation loss did not improve. Patience left: 13
# Now starting epoch: 44
# Epoch [44/100], Train Loss: 0.6135, Train Accuracy: 79.49 %
# Epoch [44/100], Validation Loss: 0.8209, Validation Accuracy: 73.44 %
# Saving model checkpoint...
# Now starting epoch: 45
# Epoch [45/100], Train Loss: 0.5986, Train Accuracy: 79.85 %
# Epoch [45/100], Validation Loss: 0.8157, Validation Accuracy: 72.94 %
# Saving model checkpoint...
# Now starting epoch: 46
# Epoch [46/100], Train Loss: 0.5876, Train Accuracy: 79.66 %
# Epoch [46/100], Validation Loss: 0.8320, Validation Accuracy: 73.44 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 47
# Epoch [47/100], Train Loss: 0.5698, Train Accuracy: 80.97 %
# Epoch [47/100], Validation Loss: 0.8902, Validation Accuracy: 70.78 %
# Validation loss did not improve. Patience left: 13
# Now starting epoch: 48
# Epoch [48/100], Train Loss: 0.5850, Train Accuracy: 80.96 %
# Epoch [48/100], Validation Loss: 0.8126, Validation Accuracy: 74.90 %
# Saving model checkpoint...
# Now starting epoch: 49
# Epoch [49/100], Train Loss: 0.5652, Train Accuracy: 81.16 %
# Epoch [49/100], Validation Loss: 0.7990, Validation Accuracy: 73.51 %
# Saving model checkpoint...
# Now starting epoch: 50
# Epoch [50/100], Train Loss: 0.5379, Train Accuracy: 81.54 %
# Epoch [50/100], Validation Loss: 0.7828, Validation Accuracy: 74.52 %
# Saving model checkpoint...
# Now starting epoch: 51
# Epoch [51/100], Train Loss: 0.5248, Train Accuracy: 82.53 %
# Epoch [51/100], Validation Loss: 0.7730, Validation Accuracy: 76.18 %
# Saving model checkpoint...
# Now starting epoch: 52
# Epoch [52/100], Train Loss: 0.5240, Train Accuracy: 82.66 %
# Epoch [52/100], Validation Loss: 0.7830, Validation Accuracy: 74.97 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 53
# Epoch [53/100], Train Loss: 0.5118, Train Accuracy: 83.15 %
# Epoch [53/100], Validation Loss: 0.7951, Validation Accuracy: 74.65 %
# Validation loss did not improve. Patience left: 13
# Now starting epoch: 54
# Epoch [54/100], Train Loss: 0.4894, Train Accuracy: 82.86 %
# Epoch [54/100], Validation Loss: 0.7726, Validation Accuracy: 74.21 %
# Saving model checkpoint...
# Now starting epoch: 55
# Epoch [55/100], Train Loss: 0.4826, Train Accuracy: 83.82 %
# Epoch [55/100], Validation Loss: 0.7611, Validation Accuracy: 76.75 %
# Saving model checkpoint...
# Now starting epoch: 56
# Epoch [56/100], Train Loss: 0.4707, Train Accuracy: 84.09 %
# Epoch [56/100], Validation Loss: 0.7644, Validation Accuracy: 75.67 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 57
# Epoch [57/100], Train Loss: 0.4570, Train Accuracy: 85.02 %
# Epoch [57/100], Validation Loss: 0.7639, Validation Accuracy: 75.98 %
# Validation loss did not improve. Patience left: 13
# Now starting epoch: 58
# Epoch [58/100], Train Loss: 0.4500, Train Accuracy: 84.70 %
# Epoch [58/100], Validation Loss: 0.7628, Validation Accuracy: 75.35 %
# Validation loss did not improve. Patience left: 12
# Now starting epoch: 59
# Epoch [59/100], Train Loss: 0.4421, Train Accuracy: 85.07 %
# Epoch [59/100], Validation Loss: 0.7998, Validation Accuracy: 74.40 %
# Validation loss did not improve. Patience left: 11
# Now starting epoch: 60
# Epoch [60/100], Train Loss: 0.4232, Train Accuracy: 85.99 %
# Epoch [60/100], Validation Loss: 0.7831, Validation Accuracy: 75.73 %
# Validation loss did not improve. Patience left: 10
# Now starting epoch: 61
# Epoch [61/100], Train Loss: 0.4423, Train Accuracy: 85.82 %
# Epoch [61/100], Validation Loss: 0.7941, Validation Accuracy: 75.03 %
# Validation loss did not improve. Patience left: 9
# Now starting epoch: 62
# Epoch [62/100], Train Loss: 0.4234, Train Accuracy: 85.75 %
# Epoch [62/100], Validation Loss: 0.7670, Validation Accuracy: 75.67 %
# Validation loss did not improve. Patience left: 8
# Now starting epoch: 63
# Epoch [63/100], Train Loss: 0.4106, Train Accuracy: 86.47 %
# Epoch [63/100], Validation Loss: 0.8053, Validation Accuracy: 75.41 %
# Validation loss did not improve. Patience left: 7
# Now starting epoch: 64
# Epoch [64/100], Train Loss: 0.4028, Train Accuracy: 86.61 %
# Epoch [64/100], Validation Loss: 0.7774, Validation Accuracy: 74.84 %
# Validation loss did not improve. Patience left: 6
# Now starting epoch: 65
# Epoch [65/100], Train Loss: 0.3899, Train Accuracy: 86.77 %
# Epoch [65/100], Validation Loss: 0.7602, Validation Accuracy: 75.86 %
# Saving model checkpoint...
# Now starting epoch: 66
# Epoch [66/100], Train Loss: 0.3717, Train Accuracy: 87.22 %
# Epoch [66/100], Validation Loss: 0.7647, Validation Accuracy: 76.11 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 67
# Epoch [67/100], Train Loss: 0.3643, Train Accuracy: 87.87 %
# Epoch [67/100], Validation Loss: 0.7716, Validation Accuracy: 76.37 %
# Validation loss did not improve. Patience left: 13
# Now starting epoch: 68
# Epoch [68/100], Train Loss: 0.3542, Train Accuracy: 88.43 %
# Epoch [68/100], Validation Loss: 0.7666, Validation Accuracy: 75.79 %
# Validation loss did not improve. Patience left: 12
# Now starting epoch: 69
# Epoch [69/100], Train Loss: 0.3550, Train Accuracy: 87.63 %
# Epoch [69/100], Validation Loss: 0.7698, Validation Accuracy: 76.94 %
# Validation loss did not improve. Patience left: 11
# Now starting epoch: 70
# Epoch [70/100], Train Loss: 0.3695, Train Accuracy: 88.13 %
# Epoch [70/100], Validation Loss: 0.7727, Validation Accuracy: 76.05 %
# Validation loss did not improve. Patience left: 10
# Now starting epoch: 71
# Epoch [71/100], Train Loss: 0.3360, Train Accuracy: 88.70 %
# Epoch [71/100], Validation Loss: 0.7249, Validation Accuracy: 77.89 %
# Saving model checkpoint...
# Now starting epoch: 72
# Epoch [72/100], Train Loss: 0.3209, Train Accuracy: 89.21 %
# Epoch [72/100], Validation Loss: 0.7854, Validation Accuracy: 76.37 %
# Validation loss did not improve. Patience left: 14
# Now starting epoch: 73
# Epoch [73/100], Train Loss: 0.3146, Train Accuracy: 89.49 %
# Epoch [73/100], Validation Loss: 0.7704, Validation Accuracy: 76.56 %
# Validation loss did not improve. Patience left: 13
# Now starting epoch: 74
# Epoch [74/100], Train Loss: 0.3240, Train Accuracy: 89.51 %
# Epoch [74/100], Validation Loss: 0.8018, Validation Accuracy: 76.43 %
# Validation loss did not improve. Patience left: 12
# Now starting epoch: 75
# Epoch [75/100], Train Loss: 0.3116, Train Accuracy: 89.24 %
# Epoch [75/100], Validation Loss: 0.8265, Validation Accuracy: 74.52 %
# Validation loss did not improve. Patience left: 11
# Now starting epoch: 76
# Epoch [76/100], Train Loss: 0.2964, Train Accuracy: 90.11 %
# Epoch [76/100], Validation Loss: 0.7641, Validation Accuracy: 76.68 %
# Validation loss did not improve. Patience left: 10
# Now starting epoch: 77
# Epoch [77/100], Train Loss: 0.2842, Train Accuracy: 90.38 %
# Epoch [77/100], Validation Loss: 0.7964, Validation Accuracy: 76.68 %
# Validation loss did not improve. Patience left: 9
# Now starting epoch: 78
# Epoch [78/100], Train Loss: 0.2966, Train Accuracy: 90.26 %
# Epoch [78/100], Validation Loss: 0.7573, Validation Accuracy: 77.13 %
# Validation loss did not improve. Patience left: 8
# Now starting epoch: 79
# Epoch [79/100], Train Loss: 0.2862, Train Accuracy: 90.46 %
# Epoch [79/100], Validation Loss: 0.7680, Validation Accuracy: 77.38 %
# Validation loss did not improve. Patience left: 7
# Now starting epoch: 80
# Epoch [80/100], Train Loss: 0.2826, Train Accuracy: 90.78 %
# Epoch [80/100], Validation Loss: 0.7779, Validation Accuracy: 76.24 %
# Validation loss did not improve. Patience left: 6
# Now starting epoch: 81
# Epoch [81/100], Train Loss: 0.2821, Train Accuracy: 90.62 %
# Epoch [81/100], Validation Loss: 0.7765, Validation Accuracy: 77.45 %
# Validation loss did not improve. Patience left: 5
# Now starting epoch: 82
# Epoch [82/100], Train Loss: 0.2482, Train Accuracy: 91.79 %
# Epoch [82/100], Validation Loss: 0.7905, Validation Accuracy: 77.70 %
# Validation loss did not improve. Patience left: 4
# Now starting epoch: 83
# Epoch [83/100], Train Loss: 0.2444, Train Accuracy: 91.90 %
# Epoch [83/100], Validation Loss: 0.7719, Validation Accuracy: 77.51 %
# Validation loss did not improve. Patience left: 3
# Now starting epoch: 84
# Epoch [84/100], Train Loss: 0.2398, Train Accuracy: 92.17 %
# Epoch [84/100], Validation Loss: 0.8032, Validation Accuracy: 75.79 %
# Validation loss did not improve. Patience left: 2
# Now starting epoch: 85
# Epoch [85/100], Train Loss: 0.2351, Train Accuracy: 92.21 %
# Epoch [85/100], Validation Loss: 0.8051, Validation Accuracy: 77.51 %
# Validation loss did not improve. Patience left: 1
# Now starting epoch: 86
# Epoch [86/100], Train Loss: 0.2391, Train Accuracy: 92.24 %
# Epoch [86/100], Validation Loss: 0.7990, Validation Accuracy: 77.38 %
# Validation loss did not improve. Patience left: 0
# Stopping training due to early stopping...
# Finished Training
# Time elapsed: 8361.03 seconds

# %%
best_checkpoint = torch.load('/content/d1_mnv2_model_checkpoint.pth')
print(best_checkpoint.keys())
model.load_state_dict(best_checkpoint['state_dict'])
# Out:
# dict_keys(['epoch', 'state_dict', 'optimizer', 'train_loss', 'val_loss'])
# <All keys matched successfully>

# %%
# Evaluate the model on the test set
model.eval()
with torch.no_grad():
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(test_dataloader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Calculate the test loss and accuracy
    test_loss = running_loss / len(test_dataloader)
    test_accuracy = 100 * correct / total
    print('Test Loss: %.4f, Test Accuracy: %.2f %%' % (test_loss, test_accuracy))
# Out:
# Test Loss: 0.7288, Test Accuracy: 79.51 %

# %%
# Calculate the ROC curve and AUC for each class
#model.eval()
true_labels = []
pred_labels = []

with torch.no_grad():
    all_labels = []
    all_probs = []
    true_labels = []
    pred_labels = []
    all_preds = []
    for i, data in enumerate(test_dataloader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        true_labels.extend(labels.cpu().numpy())
        pred_labels.extend(predicted.cpu().numpy())
        probs = torch.nn.functional.softmax(outputs, dim=1)
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())
        all_preds.extend(predicted.cpu().numpy())

    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    n_classes = len(class_names)
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(np.array(all_labels) == i, np.array(all_probs)[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curve for each class
plt.figure(figsize=(8, 8))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = %.2f)' % (roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
# Create the confusion matrix
cm = confusion_matrix(true_labels, pred_labels)
# Plot the confusion matrix with label names
plt.figure(figsize=(10, 10))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix', fontsize=16)
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=90, fontsize=12)
plt.yticks(tick_marks, class_names, fontsize=12)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

# Add the values to the cells of the confusion matrix
for i in range(len(class_names)):
    for j in range(len(class_names)):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white', fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Generate the classification report
target_names = class_names
print(classification_report(all_labels, all_preds, target_names=target_names))
# Out:
#                   precision    recall  f1-score   support
#
#          astilbe       0.61      0.81      0.70       143
#       bellflower       0.66      0.74      0.70       183
# black_eyed_susan       0.88      0.92      0.90       210
#        calendula       0.70      0.57      0.63       189
# california_poppy       0.79      0.73      0.76       230
#        carnation       0.51      0.54      0.53       161
#     common_daisy       0.75      0.82      0.78       180
#        coreopsis       0.78      0.81      0.79       208
#         daffodil       0.81      0.85      0.83       184
#        dandelion       0.90      0.87      0.89       216
#             iris       0.88      0.68      0.77       222
#         magnolia       0.66      0.72      0.69       216
#             rose       0.72      0.64      0.67       203
#        sunflower       0.95      0.91      0.93       202
#            tulip       0.82      0.89      0.85       209
#       water_lily       0.88      0.78      0.83       192
#
#         accuracy                           0.77      3148
#        macro avg       0.77      0.77      0.76      3148
#     weighted avg       0.78      0.77      0.77      3148

# %%
# Calculate and print the precision, recall, accuracy, and F1-score
precision = sum([cm[i, i] / sum(cm[:, i]) for i in range(len(target_names))]) / len(target_names)
recall = sum([cm[i, i] / sum(cm[i, :]) for i in range(len(target_names))]) / len(target_names)
accuracy = sum([cm[i, i] for i in range(len(target_names))]) / np.sum(cm)
f1_score = 2 * (precision * recall) / (precision + recall)

print('Precision: {:.2f}%'.format(precision * 100))
print('Recall: {:.2f}%'.format(recall * 100))
print('Accuracy: {:.2f}%'.format(accuracy * 100))
print('F1-score: {:.2f}%'.format(f1_score * 100))
# Out:
# Precision: 78.79%
# Recall: 78.77%
# Accuracy: 79.00%
# F1-score: 78.78%

# %%
#Saving metrics for plotting future
metrics_as_numpy = np.array(metrics)

# Save the NumPy array to a file
np.save('Dataset1_MNV2_metrics.npy', metrics_as_numpy)

# %%
# Move the model file to DRIVE

# Define the file path in the Colab environment
# d1_mnv2_model_checkpoint renamed file
model_file_path = '/content/d1_mnv2_model_checkpoint.pth'
metrics_file_path = '/content/Dataset1_MNV2_metrics.npy'

# Define the destination directory in your Google Drive
drive_dir = '/content/gdrive/MyDrive/AI Project/'

# Move the file to your Google Drive
shutil.copy(model_file_path, drive_dir)
shutil.copy(metrics_file_path, drive_dir)
# Out:
# '/content/gdrive/MyDrive/AI Project/Dataset1_MNV2_metrics.npy'
