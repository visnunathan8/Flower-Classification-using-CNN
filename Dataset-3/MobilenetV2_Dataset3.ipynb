# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import zipfile
path_to_zip_file = "/content/gdrive/MyDrive/dataset3.zip"
directory_to_extract_to = "/content/dataset3"
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %%
# !pip install torchsummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.9/dist-packages (1.5.1)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader,random_split
from torchvision import datasets, transforms, models 
from torchvision.utils import make_grid
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc
import torch.optim as optim
from tqdm import tqdm
from torchsummary import summary


import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

from sklearn.metrics import confusion_matrix
import seaborn as sns

import shutil

import warnings
warnings.filterwarnings("ignore")

# %%
BATCH_SIZE = 128
LR = 0.0001

# %%
train_transform=transforms.Compose([
        transforms.RandomRotation(10),      # rotate +/- 10 degrees
        transforms.RandomHorizontalFlip(),  # reverse 50% of images
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
])

# %% [markdown]
# # Set Train and Test

# %%
output_dir = "/content/dataset3/flowers"

# %%
dataset=datasets.ImageFolder(root=(output_dir),transform=train_transform)
dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 15740
#     Root location: /content/dataset3/flowers
#     StandardTransform
# Transform: Compose(
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                RandomHorizontalFlip(p=0.5)
#                Resize(size=224, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
class_names=dataset.classes
print(class_names)
print(len(class_names))
# Out:
# ['astilbe', 'bellflower', 'black_eyed_susan', 'calendula', 'california_poppy', 'carnation', 'common_daisy', 'coreopsis', 'daffodil', 'dandelion', 'iris', 'magnolia', 'rose', 'sunflower', 'tulip', 'water_lily']
# 16

# %%
train_size = int(0.7 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])

# %%
# Define the dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# Get the class-to-index dictionary from the original dataset
class_to_idx = train_dataset.dataset.class_to_idx

# Loop over the train dataloader and print two images for each class
for i, cls in enumerate(class_names):
    cls_idx = class_to_idx[cls]
    cls_samples = []
    for j, sample in enumerate(train_dataset):
        if sample[1] == cls_idx:
            cls_samples.append(sample[0])
        if len(cls_samples) == 2:
            break
    plt.figure(figsize=(8, 4))
    plt.suptitle(cls)
    for k, image in enumerate(cls_samples):
        plt.subplot(1, 2, k+1)
        plt.imshow(image.permute(1, 2, 0))
        plt.axis('off')
    plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class MobileNetV2(nn.Module):
    def __init__(self, num_classes=5):
        super(MobileNetV2, self).__init__()
        self.features = models.mobilenet_v2(pretrained=False).features
        self.classifier = nn.Linear(1280, num_classes)

    def forward(self, x):
        x = self.features(x)
        x = nn.functional.adaptive_avg_pool2d(x, 1).reshape(x.shape[0], -1)
        x = self.classifier(x)
        return x

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# Initialize the model and move it to the device
model = MobileNetV2(num_classes = len(class_names)).to(device)

# %%
# Display the model summary
summary(model, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 112, 112]             864
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#              ReLU6-3         [-1, 32, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112]             288
#        BatchNorm2d-5         [-1, 32, 112, 112]              64
#              ReLU6-6         [-1, 32, 112, 112]               0
#             Conv2d-7         [-1, 16, 112, 112]             512
#        BatchNorm2d-8         [-1, 16, 112, 112]              32
#   InvertedResidual-9         [-1, 16, 112, 112]               0
#            Conv2d-10         [-1, 96, 112, 112]           1,536
#       BatchNorm2d-11         [-1, 96, 112, 112]             192
#             ReLU6-12         [-1, 96, 112, 112]               0
#            Conv2d-13           [-1, 96, 56, 56]             864
#       BatchNorm2d-14           [-1, 96, 56, 56]             192
#             ReLU6-15           [-1, 96, 56, 56]               0
#            Conv2d-16           [-1, 24, 56, 56]           2,304
#       BatchNorm2d-17           [-1, 24, 56, 56]              48
#  InvertedResidual-18           [-1, 24, 56, 56]               0
#            Conv2d-19          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-20          [-1, 144, 56, 56]             288
#             ReLU6-21          [-1, 144, 56, 56]               0
#            Conv2d-22          [-1, 144, 56, 56]           1,296
#       BatchNorm2d-23          [-1, 144, 56, 56]             288
#             ReLU6-24          [-1, 144, 56, 56]               0
#            Conv2d-25           [-1, 24, 56, 56]           3,456
#       BatchNorm2d-26           [-1, 24, 56, 56]              48
#  InvertedResidual-27           [-1, 24, 56, 56]               0
#            Conv2d-28          [-1, 144, 56, 56]           3,456
#       BatchNorm2d-29          [-1, 144, 56, 56]             288
#             ReLU6-30          [-1, 144, 56, 56]               0
#            Conv2d-31          [-1, 144, 28, 28]           1,296
#       BatchNorm2d-32          [-1, 144, 28, 28]             288
#             ReLU6-33          [-1, 144, 28, 28]               0
#            Conv2d-34           [-1, 32, 28, 28]           4,608
#       BatchNorm2d-35           [-1, 32, 28, 28]              64
#  InvertedResidual-36           [-1, 32, 28, 28]               0
#            Conv2d-37          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-38          [-1, 192, 28, 28]             384
#             ReLU6-39          [-1, 192, 28, 28]               0
#            Conv2d-40          [-1, 192, 28, 28]           1,728
#       BatchNorm2d-41          [-1, 192, 28, 28]             384
#             ReLU6-42          [-1, 192, 28, 28]               0
#            Conv2d-43           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-44           [-1, 32, 28, 28]              64
#  InvertedResidual-45           [-1, 32, 28, 28]               0
#            Conv2d-46          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-47          [-1, 192, 28, 28]             384
#             ReLU6-48          [-1, 192, 28, 28]               0
#            Conv2d-49          [-1, 192, 28, 28]           1,728
#       BatchNorm2d-50          [-1, 192, 28, 28]             384
#             ReLU6-51          [-1, 192, 28, 28]               0
#            Conv2d-52           [-1, 32, 28, 28]           6,144
#       BatchNorm2d-53           [-1, 32, 28, 28]              64
#  InvertedResidual-54           [-1, 32, 28, 28]               0
#            Conv2d-55          [-1, 192, 28, 28]           6,144
#       BatchNorm2d-56          [-1, 192, 28, 28]             384
#             ReLU6-57          [-1, 192, 28, 28]               0
#            Conv2d-58          [-1, 192, 14, 14]           1,728
#       BatchNorm2d-59          [-1, 192, 14, 14]             384
#             ReLU6-60          [-1, 192, 14, 14]               0
#            Conv2d-61           [-1, 64, 14, 14]          12,288
#       BatchNorm2d-62           [-1, 64, 14, 14]             128
#  InvertedResidual-63           [-1, 64, 14, 14]               0
#            Conv2d-64          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-65          [-1, 384, 14, 14]             768
#             ReLU6-66          [-1, 384, 14, 14]               0
#            Conv2d-67          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-68          [-1, 384, 14, 14]             768
#             ReLU6-69          [-1, 384, 14, 14]               0
#            Conv2d-70           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-71           [-1, 64, 14, 14]             128
#  InvertedResidual-72           [-1, 64, 14, 14]               0
#            Conv2d-73          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-74          [-1, 384, 14, 14]             768
#             ReLU6-75          [-1, 384, 14, 14]               0
#            Conv2d-76          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-77          [-1, 384, 14, 14]             768
#             ReLU6-78          [-1, 384, 14, 14]               0
#            Conv2d-79           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-80           [-1, 64, 14, 14]             128
#  InvertedResidual-81           [-1, 64, 14, 14]               0
#            Conv2d-82          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-83          [-1, 384, 14, 14]             768
#             ReLU6-84          [-1, 384, 14, 14]               0
#            Conv2d-85          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-86          [-1, 384, 14, 14]             768
#             ReLU6-87          [-1, 384, 14, 14]               0
#            Conv2d-88           [-1, 64, 14, 14]          24,576
#       BatchNorm2d-89           [-1, 64, 14, 14]             128
#  InvertedResidual-90           [-1, 64, 14, 14]               0
#            Conv2d-91          [-1, 384, 14, 14]          24,576
#       BatchNorm2d-92          [-1, 384, 14, 14]             768
#             ReLU6-93          [-1, 384, 14, 14]               0
#            Conv2d-94          [-1, 384, 14, 14]           3,456
#       BatchNorm2d-95          [-1, 384, 14, 14]             768
#             ReLU6-96          [-1, 384, 14, 14]               0
#            Conv2d-97           [-1, 96, 14, 14]          36,864
#       BatchNorm2d-98           [-1, 96, 14, 14]             192
#  InvertedResidual-99           [-1, 96, 14, 14]               0
#           Conv2d-100          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-101          [-1, 576, 14, 14]           1,152
#            ReLU6-102          [-1, 576, 14, 14]               0
#           Conv2d-103          [-1, 576, 14, 14]           5,184
#      BatchNorm2d-104          [-1, 576, 14, 14]           1,152
#            ReLU6-105          [-1, 576, 14, 14]               0
#           Conv2d-106           [-1, 96, 14, 14]          55,296
#      BatchNorm2d-107           [-1, 96, 14, 14]             192
# InvertedResidual-108           [-1, 96, 14, 14]               0
#           Conv2d-109          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-110          [-1, 576, 14, 14]           1,152
#            ReLU6-111          [-1, 576, 14, 14]               0
#           Conv2d-112          [-1, 576, 14, 14]           5,184
#      BatchNorm2d-113          [-1, 576, 14, 14]           1,152
#            ReLU6-114          [-1, 576, 14, 14]               0
#           Conv2d-115           [-1, 96, 14, 14]          55,296
#      BatchNorm2d-116           [-1, 96, 14, 14]             192
# InvertedResidual-117           [-1, 96, 14, 14]               0
#           Conv2d-118          [-1, 576, 14, 14]          55,296
#      BatchNorm2d-119          [-1, 576, 14, 14]           1,152
#            ReLU6-120          [-1, 576, 14, 14]               0
#           Conv2d-121            [-1, 576, 7, 7]           5,184
#      BatchNorm2d-122            [-1, 576, 7, 7]           1,152
#            ReLU6-123            [-1, 576, 7, 7]               0
#           Conv2d-124            [-1, 160, 7, 7]          92,160
#      BatchNorm2d-125            [-1, 160, 7, 7]             320
# InvertedResidual-126            [-1, 160, 7, 7]               0
#           Conv2d-127            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-128            [-1, 960, 7, 7]           1,920
#            ReLU6-129            [-1, 960, 7, 7]               0
#           Conv2d-130            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-131            [-1, 960, 7, 7]           1,920
#            ReLU6-132            [-1, 960, 7, 7]               0
#           Conv2d-133            [-1, 160, 7, 7]         153,600
#      BatchNorm2d-134            [-1, 160, 7, 7]             320
# InvertedResidual-135            [-1, 160, 7, 7]               0
#           Conv2d-136            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-137            [-1, 960, 7, 7]           1,920
#            ReLU6-138            [-1, 960, 7, 7]               0
#           Conv2d-139            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-140            [-1, 960, 7, 7]           1,920
#            ReLU6-141            [-1, 960, 7, 7]               0
#           Conv2d-142            [-1, 160, 7, 7]         153,600
#      BatchNorm2d-143            [-1, 160, 7, 7]             320
# InvertedResidual-144            [-1, 160, 7, 7]               0
#           Conv2d-145            [-1, 960, 7, 7]         153,600
#      BatchNorm2d-146            [-1, 960, 7, 7]           1,920
#            ReLU6-147            [-1, 960, 7, 7]               0
#           Conv2d-148            [-1, 960, 7, 7]           8,640
#      BatchNorm2d-149            [-1, 960, 7, 7]           1,920
#            ReLU6-150            [-1, 960, 7, 7]               0
#           Conv2d-151            [-1, 320, 7, 7]         307,200
#      BatchNorm2d-152            [-1, 320, 7, 7]             640
# InvertedResidual-153            [-1, 320, 7, 7]               0
#           Conv2d-154           [-1, 1280, 7, 7]         409,600
#      BatchNorm2d-155           [-1, 1280, 7, 7]           2,560
#            ReLU6-156           [-1, 1280, 7, 7]               0
#           Linear-157                   [-1, 16]          20,496
# ================================================================
# Total params: 2,244,368
# Trainable params: 2,244,368
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 152.85
# Params size (MB): 8.56
# Estimated Total Size (MB): 161.99
# ----------------------------------------------------------------

# %%
# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LR)

# %%
# Train the model
num_epochs = 40
train_losses = []
val_losses = []
best_val_loss = float('inf')
patience = 7  # number of epochs to wait for improvement
metrics = []


for epoch in range(num_epochs):
    print(f"Now starting epoch: {epoch+1}")
    # Train the model on the training set

    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(train_dataloader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Calculate the training loss
    train_loss = running_loss / len(train_dataloader)
    train_losses.append(train_loss)
    train_accuracy = 100 * correct / total
    #print('Epoch [%d/%d], Train Loss: %.4f' % (epoch+1, num_epochs, train_loss))
    print('Epoch [%d/%d], Train Loss: %.4f, Train Accuracy: %.2f %%' % (epoch+1, num_epochs, train_loss, train_accuracy))

    """model.train()
    with torch.no_grad():
        running_loss = 0.0
        correct = 0
        total = 0
        for i, data in enumerate(train_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # Calculate the training loss and accuracy
        train_loss = running_loss / len(train_dataloader)
        train_losses.append(train_loss)
        train_accuracy = 100 * correct / total
        print('Epoch [%d/%d], Train Loss: %.4f, Train Accuracy: %.2f %%' % (epoch+1, num_epochs, train_loss, train_accuracy))"""

    # Evaluate the model on the validation set
    model.eval()
    with torch.no_grad():
        running_loss = 0.0
        correct = 0
        total = 0
        for i, data in enumerate(val_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # Calculate the validation loss and accuracy
        val_loss = running_loss / len(val_dataloader)
        val_losses.append(val_loss)
        val_accuracy = 100 * correct / total
        print('Epoch [%d/%d], Validation Loss: %.4f, Validation Accuracy: %.2f %%' % (epoch+1, num_epochs, val_loss, val_accuracy))
        metrics.append([epoch+1,train_loss,val_loss,train_accuracy,val_accuracy])

        
        # Checkpoint the model if the validation loss has improved (Early stopping)
        if val_loss < best_val_loss:
            print("Saving model checkpoint...")
            best_val_loss = val_loss
            checkpoint = {'epoch': epoch+1,
                          'state_dict': model.state_dict(),
                          'optimizer': optimizer.state_dict(),
                          'train_loss': train_loss,
                          'val_loss': val_loss}
            torch.save(checkpoint, 'd1_mnv2_model_checkpoint.pth')
            patience_counter = 0
        else:
            patience_counter += 1
            print(f"Validation loss did not improve. Patience left: {patience - patience_counter}")
            if patience_counter >= patience:
                print("Stopping training due to early stopping...")
                break
        
    # Switch the model back to training mode
    model.train()

print('Finished Training')

# Plot the training and validation loss
plt.plot(train_losses, label='Training loss')
plt.plot(val_losses, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Now starting epoch: 1
# Epoch [1/40], Train Loss: 2.5039, Train Accuracy: 16.68 %
# Epoch [1/40], Validation Loss: 2.4076, Validation Accuracy: 14.49 %
# Saving model checkpoint...
# Now starting epoch: 2
# Epoch [2/40], Train Loss: 2.1317, Train Accuracy: 26.09 %
# Epoch [2/40], Validation Loss: 2.0732, Validation Accuracy: 30.18 %
# Saving model checkpoint...
# Now starting epoch: 3
# Epoch [3/40], Train Loss: 1.9124, Train Accuracy: 34.63 %
# Epoch [3/40], Validation Loss: 1.8452, Validation Accuracy: 35.71 %
# Saving model checkpoint...
# Now starting epoch: 4
# Epoch [4/40], Train Loss: 1.6932, Train Accuracy: 41.97 %
# Epoch [4/40], Validation Loss: 1.7305, Validation Accuracy: 41.49 %
# Saving model checkpoint...
# Now starting epoch: 5
# Epoch [5/40], Train Loss: 1.5563, Train Accuracy: 46.88 %
# Epoch [5/40], Validation Loss: 1.5631, Validation Accuracy: 47.08 %
# Saving model checkpoint...
# Now starting epoch: 6
# Epoch [6/40], Train Loss: 1.4589, Train Accuracy: 49.86 %
# Epoch [6/40], Validation Loss: 1.4372, Validation Accuracy: 51.14 %
# Saving model checkpoint...
# Now starting epoch: 7
# Epoch [7/40], Train Loss: 1.3650, Train Accuracy: 52.79 %
# Epoch [7/40], Validation Loss: 1.4279, Validation Accuracy: 52.60 %
# Saving model checkpoint...
# Now starting epoch: 8
# Epoch [8/40], Train Loss: 1.2969, Train Accuracy: 55.99 %
# Epoch [8/40], Validation Loss: 1.3791, Validation Accuracy: 54.00 %
# Saving model checkpoint...
# Now starting epoch: 9
# Epoch [9/40], Train Loss: 1.2284, Train Accuracy: 58.75 %
# Epoch [9/40], Validation Loss: 1.2549, Validation Accuracy: 59.09 %
# Saving model checkpoint...
# Now starting epoch: 10
# Epoch [10/40], Train Loss: 1.1605, Train Accuracy: 60.79 %
# Epoch [10/40], Validation Loss: 1.2441, Validation Accuracy: 57.62 %
# Saving model checkpoint...
# Now starting epoch: 11
# Epoch [11/40], Train Loss: 1.1175, Train Accuracy: 62.37 %
# Epoch [11/40], Validation Loss: 1.1247, Validation Accuracy: 62.96 %
# Saving model checkpoint...
# Now starting epoch: 12
# Epoch [12/40], Train Loss: 1.0529, Train Accuracy: 64.38 %
# Epoch [12/40], Validation Loss: 1.0897, Validation Accuracy: 63.21 %
# Saving model checkpoint...
# Now starting epoch: 13
# Epoch [13/40], Train Loss: 1.0157, Train Accuracy: 65.57 %
# Epoch [13/40], Validation Loss: 1.1100, Validation Accuracy: 62.26 %
# Validation loss did not improve. Patience left: 6
# Now starting epoch: 14
# Epoch [14/40], Train Loss: 0.9788, Train Accuracy: 67.45 %
# Epoch [14/40], Validation Loss: 1.0764, Validation Accuracy: 64.74 %
# Saving model checkpoint...
# Now starting epoch: 15
# Epoch [15/40], Train Loss: 0.9275, Train Accuracy: 68.76 %
# Epoch [15/40], Validation Loss: 1.0020, Validation Accuracy: 67.66 %
# Saving model checkpoint...
# Now starting epoch: 16
# Epoch [16/40], Train Loss: 0.9048, Train Accuracy: 70.14 %
# Epoch [16/40], Validation Loss: 0.9871, Validation Accuracy: 67.85 %
# Saving model checkpoint...
# Now starting epoch: 17
# Epoch [17/40], Train Loss: 0.8729, Train Accuracy: 71.10 %
# Epoch [17/40], Validation Loss: 0.9791, Validation Accuracy: 66.96 %
# Saving model checkpoint...
# Now starting epoch: 18
# Epoch [18/40], Train Loss: 0.8197, Train Accuracy: 72.39 %
# Epoch [18/40], Validation Loss: 0.8870, Validation Accuracy: 70.71 %
# Saving model checkpoint...
# Now starting epoch: 19
# Epoch [19/40], Train Loss: 0.7962, Train Accuracy: 73.32 %
# Epoch [19/40], Validation Loss: 0.8736, Validation Accuracy: 71.47 %
# Saving model checkpoint...
# Now starting epoch: 20
# Epoch [20/40], Train Loss: 0.7726, Train Accuracy: 75.11 %
# Epoch [20/40], Validation Loss: 0.8506, Validation Accuracy: 71.47 %
# Saving model checkpoint...
# Now starting epoch: 21
# Epoch [21/40], Train Loss: 0.7335, Train Accuracy: 75.21 %
# Epoch [21/40], Validation Loss: 0.8559, Validation Accuracy: 71.92 %
# Validation loss did not improve. Patience left: 6
# Now starting epoch: 22
# Epoch [22/40], Train Loss: 0.7199, Train Accuracy: 76.02 %
# Epoch [22/40], Validation Loss: 0.8478, Validation Accuracy: 72.11 %
# Saving model checkpoint...
# Now starting epoch: 23
# Epoch [23/40], Train Loss: 0.6703, Train Accuracy: 77.78 %
# Epoch [23/40], Validation Loss: 0.8146, Validation Accuracy: 74.27 %
# Saving model checkpoint...
# Now starting epoch: 24
# Epoch [24/40], Train Loss: 0.6498, Train Accuracy: 77.80 %
# Epoch [24/40], Validation Loss: 0.7979, Validation Accuracy: 74.27 %
# Saving model checkpoint...
# Now starting epoch: 25
# Epoch [25/40], Train Loss: 0.6269, Train Accuracy: 78.54 %
# Epoch [25/40], Validation Loss: 0.8024, Validation Accuracy: 75.10 %
# Validation loss did not improve. Patience left: 6
# Now starting epoch: 26
# Epoch [26/40], Train Loss: 0.6103, Train Accuracy: 79.61 %
# Epoch [26/40], Validation Loss: 0.8045, Validation Accuracy: 74.52 %
# Validation loss did not improve. Patience left: 5
# Now starting epoch: 27
# Epoch [27/40], Train Loss: 0.5811, Train Accuracy: 80.44 %
# Epoch [27/40], Validation Loss: 0.7087, Validation Accuracy: 77.70 %
# Saving model checkpoint...
# Now starting epoch: 28
# Epoch [28/40], Train Loss: 0.5691, Train Accuracy: 81.13 %
# Epoch [28/40], Validation Loss: 0.7363, Validation Accuracy: 76.49 %
# Validation loss did not improve. Patience left: 6
# Now starting epoch: 29
# Epoch [29/40], Train Loss: 0.5662, Train Accuracy: 81.16 %
# Epoch [29/40], Validation Loss: 0.7633, Validation Accuracy: 74.78 %
# Validation loss did not improve. Patience left: 5
# Now starting epoch: 30
# Epoch [30/40], Train Loss: 0.5434, Train Accuracy: 81.68 %
# Epoch [30/40], Validation Loss: 0.6988, Validation Accuracy: 77.83 %
# Saving model checkpoint...
# Now starting epoch: 31
# Epoch [31/40], Train Loss: 0.5139, Train Accuracy: 82.66 %
# Epoch [31/40], Validation Loss: 0.7209, Validation Accuracy: 76.43 %
# Validation loss did not improve. Patience left: 6
# Now starting epoch: 32
# Epoch [32/40], Train Loss: 0.4868, Train Accuracy: 83.61 %
# Epoch [32/40], Validation Loss: 0.6991, Validation Accuracy: 78.08 %
# Validation loss did not improve. Patience left: 5
# Now starting epoch: 33
# Epoch [33/40], Train Loss: 0.4756, Train Accuracy: 83.56 %
# Epoch [33/40], Validation Loss: 0.7211, Validation Accuracy: 76.30 %
# Validation loss did not improve. Patience left: 4
# Now starting epoch: 34
# Epoch [34/40], Train Loss: 0.4497, Train Accuracy: 85.33 %
# Epoch [34/40], Validation Loss: 0.6866, Validation Accuracy: 79.03 %
# Saving model checkpoint...
# Now starting epoch: 35
# Epoch [35/40], Train Loss: 0.4299, Train Accuracy: 85.64 %
# Epoch [35/40], Validation Loss: 0.6620, Validation Accuracy: 78.14 %
# Saving model checkpoint...
# Now starting epoch: 36
# Epoch [36/40], Train Loss: 0.4011, Train Accuracy: 86.40 %
# Epoch [36/40], Validation Loss: 0.7417, Validation Accuracy: 76.87 %
# Validation loss did not improve. Patience left: 6
# Now starting epoch: 37
# Epoch [37/40], Train Loss: 0.4082, Train Accuracy: 86.43 %
# Epoch [37/40], Validation Loss: 0.7328, Validation Accuracy: 76.62 %
# Validation loss did not improve. Patience left: 5
# Now starting epoch: 38
# Epoch [38/40], Train Loss: 0.4268, Train Accuracy: 85.81 %
# Epoch [38/40], Validation Loss: 0.7232, Validation Accuracy: 78.08 %
# Validation loss did not improve. Patience left: 4
# Now starting epoch: 39
# Epoch [39/40], Train Loss: 0.3945, Train Accuracy: 87.25 %
# Epoch [39/40], Validation Loss: 0.6687, Validation Accuracy: 79.03 %
# Validation loss did not improve. Patience left: 3
# Now starting epoch: 40
# Epoch [40/40], Train Loss: 0.3942, Train Accuracy: 86.90 %
# Epoch [40/40], Validation Loss: 0.6872, Validation Accuracy: 78.40 %
# Validation loss did not improve. Patience left: 2
# Finished Training

# %%
best_checkpoint = torch.load('/content/d1_mnv2_model_checkpoint.pth')
print(best_checkpoint.keys())
model.load_state_dict(best_checkpoint['state_dict'])
# Out:
# dict_keys(['epoch', 'state_dict', 'optimizer', 'train_loss', 'val_loss'])
# <All keys matched successfully>

# %%
# Evaluate the model on the test set
model.eval()
with torch.no_grad():
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(test_dataloader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Calculate the test loss and accuracy
    test_loss = running_loss / len(test_dataloader)
    test_accuracy = 100 * correct / total
    print('Test Loss: %.4f, Test Accuracy: %.2f %%' % (test_loss, test_accuracy))
# Out:
# Test Loss: 0.6993, Test Accuracy: 77.64 %

# %%
# Calculate the ROC curve and AUC for each class
#model.eval()
true_labels = []
pred_labels = []

with torch.no_grad():
    all_labels = []
    all_probs = []
    true_labels = []
    pred_labels = []
    all_preds = []
    for i, data in enumerate(test_dataloader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        true_labels.extend(labels.cpu().numpy())
        pred_labels.extend(predicted.cpu().numpy())
        probs = torch.nn.functional.softmax(outputs, dim=1)
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())
        all_preds.extend(predicted.cpu().numpy())

    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    n_classes = len(class_names)
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(np.array(all_labels) == i, np.array(all_probs)[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curve for each class
plt.figure(figsize=(8, 8))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = %.2f)' % (roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
# Create the confusion matrix
cm = confusion_matrix(true_labels, pred_labels)
# Plot the confusion matrix with label names
plt.figure(figsize=(10, 10))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix', fontsize=16)
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=90, fontsize=12)
plt.yticks(tick_marks, class_names, fontsize=12)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

# Add the values to the cells of the confusion matrix
for i in range(len(class_names)):
    for j in range(len(class_names)):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white', fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Generate the classification report
target_names = class_names
print(classification_report(all_labels, all_preds, target_names=target_names))
# Out:
#                   precision    recall  f1-score   support
#
#          astilbe       0.80      0.60      0.68       162
#       bellflower       0.64      0.68      0.66       161
# black_eyed_susan       0.82      0.90      0.86       196
#        calendula       0.67      0.64      0.66       186
# california_poppy       0.78      0.78      0.78       213
#        carnation       0.51      0.54      0.52       174
#     common_daisy       0.86      0.76      0.81       197
#        coreopsis       0.81      0.75      0.78       213
#         daffodil       0.84      0.80      0.82       202
#        dandelion       0.90      0.89      0.89       220
#             iris       0.85      0.81      0.83       214
#         magnolia       0.65      0.77      0.71       207
#             rose       0.71      0.77      0.74       197
#        sunflower       0.88      0.93      0.90       208
#            tulip       0.81      0.89      0.85       211
#       water_lily       0.87      0.78      0.82       187
#
#         accuracy                           0.78      3148
#        macro avg       0.77      0.77      0.77      3148
#     weighted avg       0.78      0.78      0.78      3148

# %%
# Calculate and print the precision, recall, accuracy, and F1-score
precision = sum([cm[i, i] / sum(cm[:, i]) for i in range(len(target_names))]) / len(target_names)
recall = sum([cm[i, i] / sum(cm[i, :]) for i in range(len(target_names))]) / len(target_names)
accuracy = sum([cm[i, i] for i in range(len(target_names))]) / np.sum(cm)
f1_score = 2 * (precision * recall) / (precision + recall)

print('Precision: {:.2f}%'.format(precision * 100))
print('Recall: {:.2f}%'.format(recall * 100))
print('Accuracy: {:.2f}%'.format(accuracy * 100))
print('F1-score: {:.2f}%'.format(f1_score * 100))
# Out:
# Precision: 77.44%
# Recall: 76.83%
# Accuracy: 77.54%
# F1-score: 77.13%

# %%
#Saving metrics for plotting future
metrics_as_numpy = np.array(metrics)

# Save the NumPy array to a file
np.save('Dataset1_MNV2_metrics.npy', metrics_as_numpy)

# %%
# Move the model file to DRIVE

# Define the file path in the Colab environment
# d1_mnv2_model_checkpoint renamed file
model_file_path = '/content/d1_mnv2_model_checkpoint.pth'
metrics_file_path = '/content/Dataset1_MNV2_metrics.npy'

# Define the destination directory in your Google Drive
drive_dir = '/content/gdrive/MyDrive/AI Project/'

# Move the file to your Google Drive
shutil.copy(model_file_path, drive_dir)
shutil.copy(metrics_file_path, drive_dir)
# Out:
# '/content/gdrive/MyDrive/AI Project/Dataset1_MNV2_metrics.npy'
